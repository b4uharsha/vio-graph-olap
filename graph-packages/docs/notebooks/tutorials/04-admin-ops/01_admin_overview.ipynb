# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Tutorial</span>
#   <h1 class="nb-header__title">Admin Overview</h1>
#   <p class="nb-header__subtitle">Understand admin permissions and capabilities</p>
#   <div class="nb-header__meta">
#     <span class="nb-header__meta-item nb-header__meta-item--duration">15 min</span>
#     <span class="nb-header__meta-item nb-header__meta-item--level">
#       <span class="nb-difficulty nb-difficulty--intermediate">
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#       </span>
#       Intermediate
#     </span>
#   </div>
#   <div class="nb-header__tags"><span class="nb-header__tag">Admin</span><span class="nb-header__tag">Permissions</span><span class="nb-header__tag">RBAC</span></div>
# </div>

# %% [markdown]
# <div class="nb-objectives">
#   <h3 class="nb-objectives__title">What You'll Learn</h3>
#   <ul class="nb-objectives__list">
#     <li><strong>Admin Role</strong> - Understand admin vs analyst permissions</li>
#     <li><strong>Admin Operations</strong> - What admins can do that analysts can't</li>
#     <li><strong>Safety Controls</strong> - Confirmation requirements for destructive ops</li>
#     <li><strong>Audit Trail</strong> - Track admin actions</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">1</span>
#   <div>
#     <h2 class="nb-section__title">Admin vs Analyst</h2>
#     <p class="nb-section__description">Permission differences</p>
#   </div>
# </div>

# %%
# Check if client has admin permissions
if client.admin.has_permission():
    print("Admin access available")
else:
    print("Analyst access only")

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">2</span>
#   <div>
#     <h2 class="nb-section__title">Admin-Only Operations</h2>
#     <p class="nb-section__description">Bulk delete, user management</p>
#   </div>
# </div>

# %%
# Admin-only operations
# - Bulk delete resources
# - View all users' resources
# - Platform configuration
# - User management

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">3</span>
#   <div>
#     <h2 class="nb-section__title">Safety Controls</h2>
#     <p class="nb-section__description">Confirmation and audit</p>
#   </div>
# </div>

# %%
# View audit log
logs = client.admin.audit_log(limit=100)
for entry in logs:
    print(f"{entry.timestamp}: {entry.user} - {entry.action}")

# %% [markdown]
# <div class="nb-takeaways">
#   <h3 class="nb-takeaways__title">Key Takeaways</h3>
#   <ul class="nb-takeaways__list">
#     <li>Admins can perform bulk operations on any resource</li>
#     <li>Destructive operations require explicit confirmation</li>
#     <li>All admin actions are logged for audit</li>
#     <li>Use admin permissions only when necessary</li>
#   </ul>
# </div>
