# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Tutorial</span>
#   <h1 class="nb-header__title">First Cypher Queries</h1>
#   <p class="nb-header__subtitle">Learn MATCH, RETURN, and WHERE clauses</p>
#   <div class="nb-header__meta">
#     <span class="nb-header__meta-item nb-header__meta-item--duration">30 min</span>
#     <span class="nb-header__meta-item nb-header__meta-item--level">
#       <span class="nb-difficulty nb-difficulty--beginner">
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#       </span>
#       Beginner
#     </span>
#   </div>
#   <div class="nb-header__tags"><span class="nb-header__tag">Cypher</span><span class="nb-header__tag">MATCH</span><span class="nb-header__tag">WHERE</span><span class="nb-header__tag">RETURN</span></div>
# </div>

# %% [markdown]
# <div class="nb-objectives">
#   <h3 class="nb-objectives__title">What You'll Learn</h3>
#   <ul class="nb-objectives__list">
#     <li><strong>MATCH</strong> - Find patterns in the graph</li>
#     <li><strong>RETURN</strong> - Specify what to return</li>
#     <li><strong>WHERE</strong> - Filter results with conditions</li>
#     <li><strong>LIMIT</strong> - Control result size</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="nb-callout nb-callout--info">
#   <span class="nb-sr-only">Info:</span>
#   <span class="nb-callout__icon" aria-hidden="true"></span>
#   <div class="nb-callout__content">
#     <div class="nb-callout__title">Prerequisites</div>
#     <div class="nb-callout__body">Complete G1_property_graphs before this tutorial.</div>
#   </div>
# </div>

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">1</span>
#   <div>
#     <h2 class="nb-section__title">MATCH Patterns</h2>
#     <p class="nb-section__description">Finding nodes and relationships</p>
#   </div>
# </div>

# %% [markdown]
# *Content for MATCH Patterns section*

# %%
# Example code for MATCH Patterns
# TODO: Add implementation

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">2</span>
#   <div>
#     <h2 class="nb-section__title">RETURN Clauses</h2>
#     <p class="nb-section__description">What to return</p>
#   </div>
# </div>

# %% [markdown]
# *Content for RETURN Clauses section*

# %%
# Example code for RETURN Clauses
# TODO: Add implementation

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">3</span>
#   <div>
#     <h2 class="nb-section__title">WHERE Conditions</h2>
#     <p class="nb-section__description">Filtering results</p>
#   </div>
# </div>

# %% [markdown]
# *Content for WHERE Conditions section*

# %%
# Example code for WHERE Conditions
# TODO: Add implementation

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">4</span>
#   <div>
#     <h2 class="nb-section__title">Putting It Together</h2>
#     <p class="nb-section__description">Complete queries</p>
#   </div>
# </div>

# %% [markdown]
# *Content for Putting It Together section*

# %%
# Example code for Putting It Together
# TODO: Add implementation

# %% [markdown]
# <div class="nb-takeaways">
#   <h3 class="nb-takeaways__title">Key Takeaways</h3>
#   <ul class="nb-takeaways__list">
#     <li>MATCH defines the pattern to find</li>
#     <li>RETURN specifies columns in the result</li>
#     <li>WHERE filters rows based on conditions</li>
#     <li>LIMIT restricts the number of results</li>
#   </ul>
# </div>
