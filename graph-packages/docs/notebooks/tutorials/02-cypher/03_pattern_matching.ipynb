# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Tutorial</span>
#   <h1 class="nb-header__title">Pattern Matching</h1>
#   <p class="nb-header__subtitle">Variable-length paths and complex patterns</p>
#   <div class="nb-header__meta">
#     <span class="nb-header__meta-item nb-header__meta-item--duration">35 min</span>
#     <span class="nb-header__meta-item nb-header__meta-item--level">
#       <span class="nb-difficulty nb-difficulty--intermediate">
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#       </span>
#       Intermediate
#     </span>
#   </div>
#   <div class="nb-header__tags"><span class="nb-header__tag">Cypher</span><span class="nb-header__tag">Patterns</span><span class="nb-header__tag">Paths</span></div>
# </div>

# %% [markdown]
# <div class="nb-objectives">
#   <h3 class="nb-objectives__title">What You'll Learn</h3>
#   <ul class="nb-objectives__list">
#     <li><strong>Variable Paths</strong> - Match paths of varying length</li>
#     <li><strong>Path Functions</strong> - length(), nodes(), relationships()</li>
#     <li><strong>Multiple Patterns</strong> - Match complex structures</li>
#     <li><strong>Optional Matches</strong> - Handle missing patterns</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="nb-callout nb-callout--info">
#   <span class="nb-sr-only">Info:</span>
#   <span class="nb-callout__icon" aria-hidden="true"></span>
#   <div class="nb-callout__content">
#     <div class="nb-callout__title">Prerequisites</div>
#     <div class="nb-callout__body">Complete G1_property_graphs before this tutorial.</div>
#   </div>
# </div>

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">1</span>
#   <div>
#     <h2 class="nb-section__title">Variable-Length Paths</h2>
#     <p class="nb-section__description">*1..3 syntax</p>
#   </div>
# </div>

# %% [markdown]
# *Content for Variable-Length Paths section*

# %%
# Example code for Variable-Length Paths
# TODO: Add implementation

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">2</span>
#   <div>
#     <h2 class="nb-section__title">Path Functions</h2>
#     <p class="nb-section__description">Working with paths</p>
#   </div>
# </div>

# %% [markdown]
# *Content for Path Functions section*

# %%
# Example code for Path Functions
# TODO: Add implementation

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">3</span>
#   <div>
#     <h2 class="nb-section__title">Complex Patterns</h2>
#     <p class="nb-section__description">Multiple relationships</p>
#   </div>
# </div>

# %% [markdown]
# *Content for Complex Patterns section*

# %%
# Example code for Complex Patterns
# TODO: Add implementation

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">4</span>
#   <div>
#     <h2 class="nb-section__title">Optional Matches</h2>
#     <p class="nb-section__description">Handle missing data</p>
#   </div>
# </div>

# %% [markdown]
# *Content for Optional Matches section*

# %%
# Example code for Optional Matches
# TODO: Add implementation

# %% [markdown]
# <div class="nb-takeaways">
#   <h3 class="nb-takeaways__title">Key Takeaways</h3>
#   <ul class="nb-takeaways__list">
#     <li>*1..3 matches paths of length 1 to 3</li>
#     <li>shortestPath() finds minimum hops</li>
#     <li>OPTIONAL MATCH returns null for missing patterns</li>
#     <li>Path functions extract nodes and relationships</li>
#   </ul>
# </div>
