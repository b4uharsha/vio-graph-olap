# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Tutorial</span>
#   <h1 class="nb-header__title">Export Pipeline</h1>
#   <p class="nb-header__subtitle">Export graph data and algorithm results</p>
#   <div class="nb-header__meta">
#     <span class="nb-header__meta-item nb-header__meta-item--duration">25 min</span>
#     <span class="nb-header__meta-item nb-header__meta-item--level">
#       <span class="nb-difficulty nb-difficulty--advanced">
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#       </span>
#       Advanced
#     </span>
#   </div>
#   <div class="nb-header__tags"><span class="nb-header__tag">Export</span><span class="nb-header__tag">Pipeline</span><span class="nb-header__tag">Data</span><span class="nb-header__tag">Results</span></div>
# </div>

# %% [markdown]
# <div class="nb-objectives">
#   <h3 class="nb-objectives__title">What You'll Learn</h3>
#   <ul class="nb-objectives__list">
#     <li><strong>Export Types</strong> - Graph data, query results, algorithm outputs</li>
#     <li><strong>Export Formats</strong> - CSV, Parquet, JSON</li>
#     <li><strong>Pipeline Stages</strong> - Request → Processing → Ready → Download</li>
#     <li><strong>Large Exports</strong> - Handling big data exports</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">1</span>
#   <div>
#     <h2 class="nb-section__title">Export Types</h2>
#     <p class="nb-section__description">What can be exported</p>
#   </div>
# </div>

# %%
# Export query results
export = client.exports.create(
    instance_id=instance.id,
    query="MATCH (p:Person) RETURN p.name, p.pagerank",
    format="csv"
)

# Wait for export
export = client.exports.wait_for_ready(export.id)

# Download
import requests
response = requests.get(export.download_url)
with open("results.csv", "wb") as f:
    f.write(response.content)

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">2</span>
#   <div>
#     <h2 class="nb-section__title">Creating Exports</h2>
#     <p class="nb-section__description">Request an export</p>
#   </div>
# </div>

# %%
# Export entire graph
export = client.exports.create(
    instance_id=instance.id,
    export_type="graph",
    format="parquet",
    include_properties=True
)

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">3</span>
#   <div>
#     <h2 class="nb-section__title">Export Lifecycle</h2>
#     <p class="nb-section__description">Stages and status</p>
#   </div>
# </div>

# %%
# Check export status
export = client.exports.get(export_id)
print(f"Status: {export.status}")
print(f"Progress: {export.progress}%")
print(f"Size: {export.size_bytes} bytes")

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">4</span>
#   <div>
#     <h2 class="nb-section__title">Downloading Results</h2>
#     <p class="nb-section__description">Get export files</p>
#   </div>
# </div>

# %% [markdown]
# <div class="nb-takeaways">
#   <h3 class="nb-takeaways__title">Key Takeaways</h3>
#   <ul class="nb-takeaways__list">
#     <li>Export graph data, query results, or algorithm outputs</li>
#     <li>Formats: CSV (simple), Parquet (efficient), JSON (flexible)</li>
#     <li>Large exports process asynchronously</li>
#     <li>Download URLs expire after configured time</li>
#   </ul>
# </div>
