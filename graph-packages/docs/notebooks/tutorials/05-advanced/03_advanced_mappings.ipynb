# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Tutorial</span>
#   <h1 class="nb-header__title">Advanced Mappings</h1>
#   <p class="nb-header__subtitle">Copy mappings and work with mapping hierarchies</p>
#   <div class="nb-header__meta">
#     <span class="nb-header__meta-item nb-header__meta-item--duration">25 min</span>
#     <span class="nb-header__meta-item nb-header__meta-item--level">
#       <span class="nb-difficulty nb-difficulty--advanced">
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#       </span>
#       Advanced
#     </span>
#   </div>
#   <div class="nb-header__tags"><span class="nb-header__tag">Mappings</span><span class="nb-header__tag">Copy</span><span class="nb-header__tag">Hierarchy</span><span class="nb-header__tag">Versioning</span></div>
# </div>

# %% [markdown]
# <div class="nb-objectives">
#   <h3 class="nb-objectives__title">What You'll Learn</h3>
#   <ul class="nb-objectives__list">
#     <li><strong>Copying Mappings</strong> - Duplicate and modify mappings</li>
#     <li><strong>Mapping Trees</strong> - Understand parent-child relationships</li>
#     <li><strong>Version Management</strong> - Track mapping evolution</li>
#     <li><strong>Best Practices</strong> - Organize complex mapping hierarchies</li>
#   </ul>
# </div>

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">1</span>
#   <div>
#     <h2 class="nb-section__title">Copying Mappings</h2>
#     <p class="nb-section__description">Duplicate with modifications</p>
#   </div>
# </div>

# %%
# Copy a mapping with modifications
new_mapping = client.mappings.copy(
    source_id=original_mapping.id,
    name="CustomerGraph-v2",
    description="Added purchase history edges"
)

# Modify the copy
client.mappings.update(
    new_mapping.id,
    edge_definitions=[...new edges...]
)

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">2</span>
#   <div>
#     <h2 class="nb-section__title">Mapping Hierarchy</h2>
#     <p class="nb-section__description">Parent-child relationships</p>
#   </div>
# </div>

# %%
# Get mapping hierarchy tree
tree = client.mappings.get_tree(mapping.id)

print(f"Root: {tree.root.name}")
for child in tree.children:
    print(f"  └── {child.name}")
    for grandchild in child.children:
        print(f"      └── {grandchild.name}")

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">3</span>
#   <div>
#     <h2 class="nb-section__title">Version Tracking</h2>
#     <p class="nb-section__description">Evolution over time</p>
#   </div>
# </div>

# %%
# Track mapping versions
versions = client.mappings.list_versions(mapping.id)
for v in versions:
    print(f"v{v.version}: {v.created_at} - {v.description}")

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">4</span>
#   <div>
#     <h2 class="nb-section__title">Organization Patterns</h2>
#     <p class="nb-section__description">Best practices</p>
#   </div>
# </div>

# %% [markdown]
# <div class="nb-takeaways">
#   <h3 class="nb-takeaways__title">Key Takeaways</h3>
#   <ul class="nb-takeaways__list">
#     <li>Copy mappings to create variations without starting fresh</li>
#     <li>Mapping trees show lineage and relationships</li>
#     <li>Version tracking helps manage schema evolution</li>
#     <li>Use naming conventions for organized hierarchies</li>
#   </ul>
# </div>
