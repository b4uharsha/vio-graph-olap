# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Index</span>
#   <h1 class="nb-header__title">Graph Algorithms</h1>
#   <p class="nb-header__subtitle">Analyze networks with powerful graph algorithms</p>
# </div>

# %% [markdown]
# Graph algorithms unlock insights hidden in the structure of your data. This comprehensive section covers centrality measures, community detection, pathfinding, similarity metrics, and more. Start with the introduction to understand how algorithms work, then explore specific algorithm categories based on your analysis needs.

# %% [markdown]
# ## Foundations
#
# Start here to understand how graph algorithms work and how to use them effectively.

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="01_introduction.ipynb" class="nb-card">
#     <div class="nb-card__title">Introduction to Graph Algorithms</div>
#     <div class="nb-card__description">Overview of algorithm categories and when to use them</div>
#     <div class="nb-card__meta">30 min · Beginner</div>
#   </a>
#   <a href="02_understanding_results.ipynb" class="nb-card">
#     <div class="nb-card__title">Understanding Results</div>
#     <div class="nb-card__description">Interpret algorithm outputs and visualize findings</div>
#     <div class="nb-card__meta">25 min · Beginner</div>
#   </a>
#   <a href="03_performance.ipynb" class="nb-card">
#     <div class="nb-card__title">Algorithm Performance</div>
#     <div class="nb-card__description">Understand complexity, optimize memory, choose execution engine</div>
#     <div class="nb-card__meta">25 min · Intermediate</div>
#   </a>
# </div>

# %% [markdown]
# ## Centrality Algorithms
#
# Identify the most important nodes in your graph based on different definitions of importance.

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="04_finding_important_nodes.ipynb" class="nb-card">
#     <div class="nb-card__title">Finding Important Nodes</div>
#     <div class="nb-card__description">PageRank and Degree centrality for ranking node influence</div>
#     <div class="nb-card__meta">40 min · Intermediate</div>
#   </a>
#   <a href="05_bridge_detection.ipynb" class="nb-card">
#     <div class="nb-card__title">Bridge Detection</div>
#     <div class="nb-card__description">Betweenness centrality for finding critical connectors</div>
#     <div class="nb-card__meta">40 min · Intermediate</div>
#   </a>
#   <a href="06_influence_networks.ipynb" class="nb-card">
#     <div class="nb-card__title">Influence Networks</div>
#     <div class="nb-card__description">Eigenvector centrality for influence propagation</div>
#     <div class="nb-card__meta">45 min · Intermediate</div>
#   </a>
#   <a href="07_centrality_comparison.ipynb" class="nb-card">
#     <div class="nb-card__title">Centrality Comparison</div>
#     <div class="nb-card__description">When to use which centrality metric</div>
#     <div class="nb-card__meta">45 min · Advanced</div>
#   </a>
# </div>

# %% [markdown]
# ## Community Detection
#
# Find clusters and groups of densely connected nodes within your graph.

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="08_finding_communities.ipynb" class="nb-card">
#     <div class="nb-card__title">Finding Communities</div>
#     <div class="nb-card__description">Louvain and Label Propagation for cohesive groups</div>
#     <div class="nb-card__meta">45 min · Intermediate</div>
#   </a>
#   <a href="09_connected_components.ipynb" class="nb-card">
#     <div class="nb-card__title">Connected Components</div>
#     <div class="nb-card__description">WCC and SCC for isolated subgraphs</div>
#     <div class="nb-card__meta">35 min · Intermediate</div>
#   </a>
#   <a href="10_hierarchical_communities.ipynb" class="nb-card">
#     <div class="nb-card__title">Hierarchical Communities</div>
#     <div class="nb-card__description">Leiden and Girvan-Newman multi-level structure</div>
#     <div class="nb-card__meta">40 min · Advanced</div>
#   </a>
#   <a href="11_community_quality.ipynb" class="nb-card">
#     <div class="nb-card__title">Community Quality</div>
#     <div class="nb-card__description">Modularity and evaluation metrics</div>
#     <div class="nb-card__meta">30 min · Advanced</div>
#   </a>
# </div>

# %% [markdown]
# ## Pathfinding & Traversal
#
# Find optimal routes and explore connectivity patterns in your graph.

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="12_shortest_paths.ipynb" class="nb-card">
#     <div class="nb-card__title">Shortest Paths</div>
#     <div class="nb-card__description">BFS, Dijkstra, and weighted pathfinding</div>
#     <div class="nb-card__meta">40 min · Intermediate</div>
#   </a>
#   <a href="13_network_connectivity.ipynb" class="nb-card">
#     <div class="nb-card__title">Network Connectivity</div>
#     <div class="nb-card__description">BFS/DFS traversal and reachability</div>
#     <div class="nb-card__meta">40 min · Intermediate</div>
#   </a>
#   <a href="14_spanning_trees.ipynb" class="nb-card">
#     <div class="nb-card__title">Spanning Trees</div>
#     <div class="nb-card__description">MST for optimal connectivity</div>
#     <div class="nb-card__meta">35 min · Intermediate</div>
#   </a>
# </div>

# %% [markdown]
# ## Similarity & Link Prediction
#
# Measure how similar nodes are and predict missing connections.

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="15_node_similarity.ipynb" class="nb-card">
#     <div class="nb-card__title">Node Similarity</div>
#     <div class="nb-card__description">Jaccard, Cosine, and structural similarity</div>
#     <div class="nb-card__meta">40 min · Intermediate</div>
#   </a>
#   <a href="16_predicting_connections.ipynb" class="nb-card">
#     <div class="nb-card__title">Predicting Connections</div>
#     <div class="nb-card__description">Link prediction algorithms</div>
#     <div class="nb-card__meta">45 min · Advanced</div>
#   </a>
#   <a href="17_recommendations.ipynb" class="nb-card">
#     <div class="nb-card__title">Recommendation Systems</div>
#     <div class="nb-card__description">Graph-based recommendations</div>
#     <div class="nb-card__meta">45 min · Advanced</div>
#   </a>
# </div>

# %% [markdown]
# ## Network Metrics
#
# Measure global and local properties of your graph structure.

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="18_network_density.ipynb" class="nb-card">
#     <div class="nb-card__title">Network Density</div>
#     <div class="nb-card__description">Triangle counting and clustering</div>
#     <div class="nb-card__meta">30 min · Intermediate</div>
#   </a>
#   <a href="19_core_decomposition.ipynb" class="nb-card">
#     <div class="nb-card__title">Core Decomposition</div>
#     <div class="nb-card__description">K-Core analysis</div>
#     <div class="nb-card__meta">25 min · Intermediate</div>
#   </a>
#   <a href="20_network_metrics.ipynb" class="nb-card">
#     <div class="nb-card__title">Network Metrics</div>
#     <div class="nb-card__description">Global statistics</div>
#     <div class="nb-card__meta">30 min · Intermediate</div>
#   </a>
# </div>

# %% [markdown]
# ## Advanced Topics
#
# Take your graph analysis to the next level with embeddings, pipelines, and real-world applications.

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="21_graph_embeddings.ipynb" class="nb-card">
#     <div class="nb-card__title">Graph Embeddings</div>
#     <div class="nb-card__description">Node2Vec for ML feature generation</div>
#     <div class="nb-card__meta">50 min · Advanced</div>
#   </a>
#   <a href="22_combining_algorithms.ipynb" class="nb-card">
#     <div class="nb-card__title">Combining Algorithms</div>
#     <div class="nb-card__description">Multi-algorithm workflows and ensemble approaches</div>
#     <div class="nb-card__meta">45 min · Advanced</div>
#   </a>
#   <a href="23_case_studies.ipynb" class="nb-card">
#     <div class="nb-card__title">Real-World Case Studies</div>
#     <div class="nb-card__description">Fraud detection, social analysis, and recommendations</div>
#     <div class="nb-card__meta">60 min · Advanced</div>
#   </a>
# </div>

# %% [markdown]
# <div class="nb-navigation">
#   <div class="nb-navigation__title">Next Steps</div>
#   <div class="nb-card-grid">
#     <a href="../04-admin-ops/_index.ipynb" class="nb-card">
#       <div class="nb-card__title">Admin & Operations</div>
#       <div class="nb-card__description">Platform administration, bulk operations, and configuration</div>
#       <div class="nb-card__meta">4 tutorials · ~1.5 hours</div>
#     </a>
#     <a href="../05-advanced/_index.ipynb" class="nb-card">
#       <div class="nb-card__title">Advanced Topics</div>
#       <div class="nb-card__description">Instance lifecycle, export pipelines, and graph engine selection</div>
#       <div class="nb-card__meta">5 tutorials · ~2 hours</div>
#     </a>
#   </div>
# </div>
