# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Welcome</span>
#   <h1 class="nb-header__title">Graph OLAP Notebooks</h1>
#   <p class="nb-header__subtitle">Interactive documentation for the Graph OLAP platform</p>
# </div>

# %% [markdown]
# Welcome to the Graph OLAP notebook documentation. This curriculum provides comprehensive coverage of the platform through interactive Jupyter notebooks. Whether you're just getting started or looking for detailed API reference, you'll find what you need here.

# %% [markdown]
# ## Documentation Sections

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="tutorials/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Tutorials</div>
#     <div class="nb-card__description">Learn Graph OLAP step by step with progressive tutorials covering SDK fundamentals, Cypher queries, and graph algorithms</div>
#     <div class="nb-card__meta">6 tracks · Beginner to Advanced · ~8 hours total</div>
#   </a>
#   <a href="reference/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Reference</div>
#     <div class="nb-card__description">Complete API documentation for SDK classes, methods, and graph algorithms with parameters and examples</div>
#     <div class="nb-card__meta">9 SDK classes · 22 algorithms · 6 categories</div>
#   </a>
#   <a href="examples/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Examples</div>
#     <div class="nb-card__description">Real-world use case examples demonstrating SDK patterns, workflows, and best practices</div>
#     <div class="nb-card__meta">19 runnable examples</div>
#   </a>
# </div>

# %% [markdown]
# <div class="nb-navigation">
#   <div class="nb-navigation__title">Getting Started</div>
#   <div class="nb-navigation__subtitle">New to Graph OLAP? Start here.</div>
#   <div class="nb-card-grid">
#     <a href="tutorials/00-start-here/01_quick_start.ipynb" class="nb-card">
#       <div class="nb-card__title">Quick Start</div>
#       <div class="nb-card__description">Create your first graph and run queries in 5 minutes</div>
#       <div class="nb-card__meta">5 min · Beginner</div>
#     </a>
#     <a href="tutorials/01-fundamentals/_index.ipynb" class="nb-card">
#       <div class="nb-card__title">SDK Fundamentals</div>
#       <div class="nb-card__description">Master the core concepts: connections, mappings, snapshots, and instances</div>
#       <div class="nb-card__meta">8 tutorials · ~3 hours</div>
#     </a>
#   </div>
# </div>
