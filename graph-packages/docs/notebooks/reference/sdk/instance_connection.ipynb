# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Reference</span>
#   <h1 class="nb-header__title">InstanceConnection</h1>
#   <p class="nb-header__subtitle">Query execution interface</p>
#   <div class="nb-header__meta">
#     <span class="nb-header__meta-item nb-header__meta-item--duration">10 min</span>
#     <span class="nb-header__meta-item nb-header__meta-item--level">
#       <span class="nb-difficulty nb-difficulty--intermediate">
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#       </span>
#       Intermediate
#     </span>
#   </div>
#   <div class="nb-header__tags"><span class="nb-header__tag">Reference</span><span class="nb-header__tag">API</span></div>
# </div>

# %% [markdown]
# ## InstanceConnection
#
# Query execution interface

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">1</span>
#   <div>
#     <h2 class="nb-section__title">Methods</h2>
#     <p class="nb-section__description">API reference</p>
#   </div>
# </div>

# %% [markdown]
# ### `query()`
#
# *Method documentation*

# %%
# Example usage of query
# TODO: Add implementation

# %% [markdown]
# ### `query_df()`
#
# *Method documentation*

# %%
# Example usage of query_df
# TODO: Add implementation

# %% [markdown]
# ### `query_scalar()`
#
# *Method documentation*

# %%
# Example usage of query_scalar
# TODO: Add implementation

# %% [markdown]
# ### `close()`
#
# *Method documentation*

# %%
# Example usage of close
# TODO: Add implementation

# %% [markdown]
# <div class="nb-takeaways">
#   <h3 class="nb-takeaways__title">Key Takeaways</h3>
#   <ul class="nb-takeaways__list">
#     <li>InstanceConnection provides query execution interface</li>
#     <li>Key methods: query, query_df, query_scalar</li>
#   </ul>
# </div>
