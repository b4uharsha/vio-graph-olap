# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Reference</span>
#   <h1 class="nb-header__title">Pathfinding Algorithms</h1>
#   <p class="nb-header__subtitle">Find optimal routes and explore graph structure</p>
# </div>

# %% [markdown]
# ## Overview
#
# Pathfinding algorithms find routes between nodes in a graph. They are fundamental to:
#
# - Navigation and routing
# - Network analysis
# - Dependency resolution
# - Game AI and planning

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="shortest_path.ipynb" class="nb-card">
#     <div class="nb-card__title">Shortest Path</div>
#     <div class="nb-card__description">Find the shortest path between nodes</div>
#     <div class="nb-card__meta">O(V+E) unweighted · Beginner</div>
#   </a>
#   <a href="dijkstra.ipynb" class="nb-card">
#     <div class="nb-card__title">Dijkstra's Algorithm</div>
#     <div class="nb-card__description">Find weighted shortest paths from a source node</div>
#     <div class="nb-card__meta">O((V+E)·log V) · Intermediate</div>
#   </a>
#   <a href="bfs.ipynb" class="nb-card">
#     <div class="nb-card__title">Breadth-First Search</div>
#     <div class="nb-card__description">Explore graphs level by level</div>
#     <div class="nb-card__meta">O(V+E) · Beginner</div>
#   </a>
# </div>
