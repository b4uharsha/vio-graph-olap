# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Reference</span>
#   <h1 class="nb-header__title">Breadth-First Search</h1>
#   <p class="nb-header__subtitle">Traverse graph level by level from source</p>
#   <div class="nb-header__meta">
#     <span class="nb-header__meta-item nb-header__meta-item--duration">10 min</span>
#     <span class="nb-header__meta-item nb-header__meta-item--level">
#       <span class="nb-difficulty nb-difficulty--intermediate">
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#         <span class="nb-difficulty__dot"></span>
#       </span>
#       Intermediate
#     </span>
#   </div>
#   <div class="nb-header__tags"><span class="nb-header__tag">Pathfinding</span><span class="nb-header__tag">Traversal</span><span class="nb-header__tag">FalkorDB</span></div>
# </div>

# %% [markdown]
# ## Overview
#
# **Category:** Pathfinding
# **Complexity:** O(V+E)
#
# Traverse graph level by level from source

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">1</span>
#   <div>
#     <h2 class="nb-section__title">Parameters</h2>
#     <p class="nb-section__description">Configuration options</p>
#   </div>
# </div>

# %% [markdown]
# | Parameter | Type | Default | Description |
# |-----------|------|---------|-------------|
# | label | str | required | Node label to process |
# | write_property | str | required | Property to store results |

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">2</span>
#   <div>
#     <h2 class="nb-section__title">Basic Usage</h2>
#     <p class="nb-section__description">Simple example</p>
#   </div>
# </div>

# %%
# Run Breadth-First Search
conn.algorithms.bfs(
    label="Person",
    write_property="result"
)

# %% [markdown]
# <div class="nb-section">
#   <span class="nb-section__number">3</span>
#   <div>
#     <h2 class="nb-section__title">Query Results</h2>
#     <p class="nb-section__description">Access algorithm output</p>
#   </div>
# </div>

# %%
# Query results
result = conn.query("""
    MATCH (n)
    RETURN n.name, n.result
    ORDER BY n.result DESC
    LIMIT 10
""")

# %% [markdown]
# <div class="nb-takeaways">
#   <h3 class="nb-takeaways__title">Key Takeaways</h3>
#   <ul class="nb-takeaways__list">
#     <li>Breadth-First Search measures pathfinding</li>
#     <li>Time complexity: O(V+E)</li>
#     <li>Results stored as node properties</li>
#   </ul>
# </div>
