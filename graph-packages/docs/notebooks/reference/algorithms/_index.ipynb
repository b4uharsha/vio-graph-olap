# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Reference</span>
#   <h1 class="nb-header__title">Graph Algorithms</h1>
#   <p class="nb-header__subtitle">Comprehensive algorithm reference by category</p>
# </div>

# %% [markdown]
# ## Overview
#
# This reference covers graph algorithms organized by category. Each algorithm page includes:
#
# - Mathematical definition and complexity
# - Parameter reference
# - Code examples with the GraphOLAP SDK
# - Best practices and related algorithms

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="centrality/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Centrality</div>
#     <div class="nb-card__description">Measure node importance and influence</div>
#     <div class="nb-card__meta">5 algorithms</div>
#   </a>
#   <a href="community/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Community Detection</div>
#     <div class="nb-card__description">Find groups of densely connected nodes</div>
#     <div class="nb-card__meta">4 algorithms</div>
#   </a>
#   <a href="pathfinding/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Pathfinding</div>
#     <div class="nb-card__description">Find optimal routes and explore structure</div>
#     <div class="nb-card__meta">3 algorithms</div>
#   </a>
#   <a href="similarity/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Similarity</div>
#     <div class="nb-card__description">Measure node similarity for link prediction</div>
#     <div class="nb-card__meta">4 algorithms</div>
#   </a>
#   <a href="structural/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Structural</div>
#     <div class="nb-card__description">Analyze graph topology and connectivity</div>
#     <div class="nb-card__meta">5 algorithms</div>
#   </a>
#   <a href="embeddings/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Embeddings</div>
#     <div class="nb-card__description">Learn vector representations of nodes</div>
#     <div class="nb-card__meta">1 algorithm</div>
#   </a>
# </div>
