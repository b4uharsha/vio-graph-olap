# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Reference</span>
#   <h1 class="nb-header__title">Similarity Algorithms</h1>
#   <p class="nb-header__subtitle">Measure node similarity for link prediction</p>
# </div>

# %% [markdown]
# ## Overview
#
# Similarity algorithms compute how alike two nodes are based on their neighborhood structure. Primary applications include:
#
# - **Link prediction**: Predict missing or future edges
# - **Recommendation**: Suggest connections
# - **Duplicate detection**: Find similar entities

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="common_neighbors.ipynb" class="nb-card">
#     <div class="nb-card__title">Common Neighbors</div>
#     <div class="nb-card__description">Count shared connections for link prediction</div>
#     <div class="nb-card__meta">O(d) per pair · Beginner</div>
#   </a>
#   <a href="jaccard.ipynb" class="nb-card">
#     <div class="nb-card__title">Jaccard Coefficient</div>
#     <div class="nb-card__description">Measure neighborhood overlap between node pairs</div>
#     <div class="nb-card__meta">O(d) per pair · Beginner</div>
#   </a>
#   <a href="adamic_adar.ipynb" class="nb-card">
#     <div class="nb-card__title">Adamic-Adar Index</div>
#     <div class="nb-card__description">Weight common neighbors by their rarity</div>
#     <div class="nb-card__meta">O(d) per pair · Intermediate</div>
#   </a>
#   <a href="preferential_attachment.ipynb" class="nb-card">
#     <div class="nb-card__title">Preferential Attachment</div>
#     <div class="nb-card__description">Predict links using rich-get-richer model</div>
#     <div class="nb-card__meta">O(1) per pair · Beginner</div>
#   </a>
# </div>
