# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Reference</span>
#   <h1 class="nb-header__title">Structural Algorithms</h1>
#   <p class="nb-header__subtitle">Analyze graph topology and connectivity</p>
# </div>

# %% [markdown]
# ## Overview
#
# Structural algorithms analyze the topology and connectivity patterns of graphs:
#
# - **Connected Components**: Find isolated subgraphs
# - **K-Core**: Identify dense regions
# - **Triangles & Clustering**: Measure local cohesion

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="weakly_connected.ipynb" class="nb-card">
#     <div class="nb-card__title">Weakly Connected Components</div>
#     <div class="nb-card__description">Find connected subgraphs ignoring edge direction</div>
#     <div class="nb-card__meta">O(V+E) · Beginner</div>
#   </a>
#   <a href="strongly_connected.ipynb" class="nb-card">
#     <div class="nb-card__title">Strongly Connected Components</div>
#     <div class="nb-card__description">Find subgraphs with mutual reachability</div>
#     <div class="nb-card__meta">O(V+E) · Intermediate</div>
#   </a>
#   <a href="kcore.ipynb" class="nb-card">
#     <div class="nb-card__title">K-Core Decomposition</div>
#     <div class="nb-card__description">Find dense subgraphs where all nodes have degree >= k</div>
#     <div class="nb-card__meta">O(V+E) · Intermediate</div>
#   </a>
#   <a href="triangle_count.ipynb" class="nb-card">
#     <div class="nb-card__title">Triangle Count</div>
#     <div class="nb-card__description">Count triangles to measure local clustering</div>
#     <div class="nb-card__meta">O(E^1.5) · Intermediate</div>
#   </a>
#   <a href="clustering_coefficient.ipynb" class="nb-card">
#     <div class="nb-card__title">Clustering Coefficient</div>
#     <div class="nb-card__description">Measure how tightly connected node neighborhoods are</div>
#     <div class="nb-card__meta">O(V·d²) · Intermediate</div>
#   </a>
# </div>
