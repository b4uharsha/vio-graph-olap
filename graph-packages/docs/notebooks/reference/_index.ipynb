# %% [markdown]
# <div class="nb-header">
#   <span class="nb-header__type">Reference</span>
#   <h1 class="nb-header__title">Reference Documentation</h1>
#   <p class="nb-header__subtitle">SDK classes, methods, and algorithm reference</p>
# </div>

# %% [markdown]
# ## Overview
#
# This reference section provides detailed documentation for the GraphOLAP platform:
#
# - **SDK Reference**: Python client, resources, and managers
# - **Algorithm Reference**: Graph algorithms with mathematical definitions, parameters, and examples

# %% [markdown]
# <div class="nb-card-grid">
#   <a href="sdk/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">SDK Reference</div>
#     <div class="nb-card__description">GraphOLAP Python SDK classes and methods</div>
#     <div class="nb-card__meta">9 classes</div>
#   </a>
#   <a href="algorithms/_index.ipynb" class="nb-card">
#     <div class="nb-card__title">Graph Algorithms</div>
#     <div class="nb-card__description">Comprehensive algorithm reference by category</div>
#     <div class="nb-card__meta">22 algorithms · 6 categories</div>
#   </a>
# </div>
